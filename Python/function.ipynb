# %%
# %pylab inline
import pandas as pd
matplotlib.style.use('ggplot')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### 函数

# %% [markdown]
# $$y=ax + b$$

# %%
x = linspace(-5, 5, 200)
y = lambda x : 3 * x -5
plot(x, y(x), color='green', label='$y=3x-5$')
xlabel('x')
ylabel('y')
legend(['$y=3x-5$'])

# %% [markdown]
# $$y=ax^2 + bx +c$$
# 它的对称轴为直线
# $$x=-\frac{b}{2a}$$

# %%
x = linspace(-5, 7, 200)
y = lambda x : 2 * (x**2) - 3 * x -5

m = (3/4) * ones(20)
g = linspace(-20, 80, 20)

plot(x, y(x), m, g)
xlabel('x')
ylabel('y')
legend(['$y=2x^2-3x-5$', '$x=3/4$'])

# %% [markdown]
# $$y=\frac{a}{x}$$

# %%
x = linspace(-2, 2, 200)
y = lambda x : 3/x
plot(x, y(x), color='green')
xlabel('x')
ylabel('y')
legend(['$y=3/x$'])

# %% [markdown]
# $$y=asin(x)$$

# %%
x = linspace(-10, 10, 200)
y = lambda x : 2*sin(x)
plot(x, y(x), color='green')
xlabel('x')
ylabel('y')
legend(['$y=2sin(x)$'])

# %% [markdown]
# $$y=acos(x)$$

# %%
x = linspace(-10, 10, 200)
y = lambda x : 2*cos(x)
plot(x, y(x), color='green')
xlabel('x')
ylabel('y')
legend(['$y=2cos(x)$'])

# %% [markdown]
# $$y=atan(x)$$

# %%
x = linspace(-3, 3, 200)
y = lambda x : 2*tan(x)
plot(x, y(x), color='green')
xlabel('x')
ylabel('y')
legend(['$y=2tan(x)$'])

# %% [markdown]
# $$y=a^x$$

# %%
x = linspace(-5, 5, 200)
y = lambda x : 3**x
plot(x, y(x), color='green')
xlabel('x')
ylabel('y')
legend(['$y=3^x$'])

# %% [markdown]
# $$y=log_ax$$

# %%
x = linspace(-3, 3, 200)
y = lambda x : log2(x)
plot(x, y(x), color='green')
xlabel('x')
ylabel('y')
legend(['$y=log_2x$'])
# Out:
# <ipython-input-9-93084b8dc8cc>:2: RuntimeWarning: invalid value encountered in log2
#   y = lambda x : log2(x)
