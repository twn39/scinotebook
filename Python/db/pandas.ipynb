# %%
# %pylab inline
import pandas as pd
matplotlib.style.use('ggplot')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('mysql+mysqlconnector://root:tangweinan@localhost/gili')

# %%
with engine.connect() as conn, conn.begin():
    data = pd.read_sql_table('stats', conn, index_col='date', parse_dates={'date': '%Y-%m-%d'}, columns=['users', 'out_comers'])

# %%
data
# Out:
#             users  out_comers
# date
# 2017-06-16      0           0
# 2017-06-19      0           0
# 2017-06-18      0           4
# 2017-06-17      0           0
# 2017-06-15      2           0
# 2017-06-14      0           1
# 2017-06-13      1           0
# 2017-06-12      0           0
# 2017-06-11      0           2
# 2017-06-10      0           0
# 2017-06-09      2           0
# 2017-06-08      0           0
# 2017-06-07      0           0
# 2017-06-06      0           0

# %%
data.plot(subplots=True, figsize=(18, 6))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000250B6940DD8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000250B6B548D0>], dtype=object)

# %%
data.plot(figsize=(18, 6))
