# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams["figure.figsize"] = (14, 6)
plt.style.use('ggplot')
plt.rcParams["font.sans-serif"] = 'SimSun'
import akshare as ak
import pandas as pd

# %%
df = ak.stock_zh_a_hist(symbol="600585", period="daily", start_date="20180101", end_date='20230120', adjust="")
df = df.set_index("日期")
df.index = pd.to_datetime(df.index)
df
# Out:
#                开盘     收盘     最高     最低      成交量           成交额    振幅   涨跌幅  \
# 日期
# 2018-01-02  29.80  31.96  32.10  29.53  1064146  3.276283e+09  8.76  8.97
# 2018-01-03  32.20  31.68  32.72  31.65   788426  2.532120e+09  3.35 -0.88
# 2018-01-04  31.66  32.10  32.76  31.66   531271  1.712135e+09  3.47  1.33
# 2018-01-05  32.29  32.65  33.33  32.13   610326  1.996939e+09  3.74  1.71
# 2018-01-08  33.97  33.97  35.50  33.39   899759  3.080599e+09  6.46  4.04
# ...           ...    ...    ...    ...      ...           ...   ...   ...
# 2023-01-16  28.84  29.32  29.64  28.77   253244  7.421972e+08  3.01  1.38
# 2023-01-17  29.33  29.19  29.48  28.95   134392  3.920414e+08  1.81 -0.44
# 2023-01-18  29.18  29.03  29.29  28.80   152553  4.421984e+08  1.68 -0.55
# 2023-01-19  29.00  29.06  29.08  28.76   177665  5.142493e+08  1.10  0.10
# 2023-01-20  29.07  29.48  29.49  28.96   163923  4.804211e+08  1.82  1.45
#
#              涨跌额   换手率
# 日期
# 2018-01-02  2.63  2.66
# ...

# %%
df['收盘'].plot(xlabel="日期", ylabel='收盘', title='海螺水泥（SH600585）')
# Out:
# <AxesSubplot: title={'center': '海螺水泥（SH600585）'}, xlabel='日期', ylabel='收盘'>

# %%
df = ak.stock_financial_report_sina(stock="600585", symbol="现金流量表")
df = df.set_index("报表日期")
df.index = pd.to_datetime(df.index)
df
# Out:
#            单位 一、经营活动产生的现金流量   销售商品、提供劳务收到的现金      收到的税费返还 收到的其他与经营活动有关的现金  \
# 报表日期
# 2022-09-30  元           NaN  103977302380.00  17360612.00   1282938307.00
# 2022-06-30  元           NaN   68258141738.00  15459137.00    954221182.00
# 2022-03-31  元           NaN   32412756198.00   5438975.00    543839439.00
# 2021-12-31  元           NaN  200645299274.00  24240677.00   2084430868.00
# 2021-09-30  元           NaN  141553852062.00  13067747.00   1469395637.00
# ...        ..           ...              ...          ...             ...
# 2002-06-30  元           NaN    1570462569.00  21152839.00      6902737.00
# 2001-12-31  元           NaN    2607881978.00  55450833.00     88587524.00
# 2001-06-30  元           NaN                0            0               0
# 2000-12-31  元           NaN    1569067701.00  27858303.00      5411782.00
# 1999-12-31  元           NaN    1292419332.00  22965738.00        76519.00
#
# ...

# %%
df = ak.stock_a_pe(symbol="000300.XSHG")
df = df.set_index("date")
df.index = pd.to_datetime(df.index)
df[['averagePELYR', 'averagePETTM', 'middlePETTM']].plot()
# Out:
# <AxesSubplot: xlabel='date'>

# %%
df = ak.stock_a_pb(symbol="000300.XSHG")
df = df.set_index("date")
df.index = pd.to_datetime(df.index)
df
# Out:
#             equalWeightAveragePB  middlePB  weightingAveragePB    close
# date
# 2005-04-08                  2.06      1.90                 0.0  1003.45
# 2005-04-11                  2.10      1.94                 0.0   995.42
# 2005-04-12                  2.09      1.93                 0.0   978.70
# 2005-04-13                  2.05      1.89                 0.0  1000.90
# 2005-04-14                  2.10      1.95                 0.0   986.98
# ...                          ...       ...                 ...      ...
# 2023-01-18                  4.24      2.73                 0.0  4130.31
# 2023-01-19                  4.27      2.78                 0.0  4156.01
# 2023-01-29                  4.28      2.78                 0.0  4181.53
# 2023-01-30                  4.31      2.76                 0.0  4201.35
# 2023-01-31                  4.25      2.73                 0.0  4156.86
#
# [4320 rows x 4 columns]

# %%
df[['equalWeightAveragePB', 'middlePB']].plot()
# Out:
# <AxesSubplot: xlabel='date'>
