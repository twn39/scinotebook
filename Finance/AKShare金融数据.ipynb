# %%
# !pip install akshare -qq

# %%
import matplotlib
from matplotlib import font_manager

font_files = matplotlib.font_manager.findSystemFonts('/usr/share/fonts/opentype/noto')
for font_file in font_files:
    print(font_file)
    font_manager.fontManager.addfont(font_file)
# Out:
# /usr/share/fonts/opentype/noto/NotoSerifCJK-Bold.ttc
# /usr/share/fonts/opentype/noto/NotoSerifCJK-Regular.ttc
# /usr/share/fonts/opentype/noto/NotoSansCJK-Bold.ttc
# /usr/share/fonts/opentype/noto/NotoSansCJK-Regular.ttc

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['font.family'] = ['Noto Sans CJK JP']  # 需要放在 plt.style.use 后面覆盖默认字体
plt.rcParams['axes.unicode_minus'] = False

import akshare as ak
import pandas as pd

# %%
df = ak.stock_zh_a_hist(symbol="600585", period="daily", start_date="20220101", end_date='20250120', adjust="")
df = df.set_index("日期")
df.index = pd.to_datetime(df.index)
df
# Out:
#               股票代码     开盘     收盘     最高     最低     成交量           成交额    振幅  \
# 日期
# 2022-01-04  600585  40.46  41.67  41.85  40.02  270855  1.114937e+09  4.54
# 2022-01-05  600585  41.55  42.26  42.58  41.34  330895  1.392407e+09  2.98
# 2022-01-06  600585  42.50  43.29  44.15  42.32  422651  1.836496e+09  4.33
# 2022-01-07  600585  43.20  43.96  44.15  43.15  372866  1.640295e+09  2.31
# 2022-01-10  600585  43.96  43.88  44.50  43.40  252064  1.105379e+09  2.50
# ...            ...    ...    ...    ...    ...     ...           ...   ...
# 2024-12-26  600585  24.48  23.90  24.51  23.62  213652  5.105333e+08  3.63
# 2024-12-27  600585  23.92  24.03  24.11  23.78  133131  3.192703e+08  1.38
# 2024-12-30  600585  24.00  23.99  24.25  23.82  143283  3.430563e+08  1.79
# 2024-12-31  600585  24.07  23.78  24.22  23.78  153339  3.679718e+08  1.83
# 2025-01-02  600585  23.77  23.42  24.10  23.40  129228  3.059079e+08  2.94
#
#              涨跌幅   涨跌额   换手率
# 日期
# ...

# %%
df['收盘'].plot(xlabel="日期", ylabel='收盘', title='海螺水泥（SH600585）')
# Out:
# <Axes: title={'center': '海螺水泥（SH600585）'}, xlabel='日期', ylabel='收盘'>

# %%
df = ak.stock_financial_report_sina(stock="600585", symbol="现金流量表")
df
# Out:
#          报告日 经营活动产生的现金流量  销售商品、提供劳务收到的现金 客户存款和同业存放款项净增加额 向中央银行借款净增加额  \
# 0   20240930         NaN   80814773640.0             NaN         NaN
# 1   20240630         NaN   56612517898.0             NaN         NaN
# 2   20240331         NaN   25072806098.0             NaN         NaN
# 3   20231231         NaN  171550099544.0             NaN         NaN
# 4   20230930         NaN  113568072927.0             NaN         NaN
# ..       ...         ...             ...             ...         ...
# 88  20020630         NaN    1570462569.0             NaN         NaN
# 89  20011231         NaN    2607881978.0             NaN         NaN
# 90  20010630         NaN             NaN             NaN         NaN
# 91  20001231         NaN    1569067701.0             NaN         NaN
# 92  19991231         NaN    1292419332.0             NaN         NaN
#
#    向其他金融机构拆入资金净增加额 收到原保险合同保费取得的现金 收到再保险业务现金净额 保户储金及投资款净增加额 处置交易性金融资产净增加额  ...  \
# ...
